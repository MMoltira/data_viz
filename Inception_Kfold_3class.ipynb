# %% [markdown]
# <a href="https://colab.research.google.com/github/MMoltira/data_viz/blob/main/Inception_Kfold_3class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### import

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import cv2
import numpy as np
import pandas as pd
from torchsummary import summary
from skimage.io import imread, imsave
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from imutils import paths
import argparse

from sklearn.model_selection import KFold
from sklearn import metrics
from scipy.stats import zscore


import matplotlib.image as mpimg
from matplotlib.pyplot import savefig

import itertools
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
import pickle
import joblib

# %% [markdown]
# ######Load data // KKUmail

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/My Drive/Projectsenior/Image'

# %% [markdown]
# train 3 class

# %%
Normal151_dir = os.path.join(data_dir,'Normal151')
TB150_dir = os.path.join(data_dir,'TB150')
CA150_dir = os.path.join(data_dir,'CA150')

All_3class_dir = os.path.join(data_dir,'All_3class')

# %% [markdown]
# ######Load data // Gmail

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/My Drive/Projectsenior/image'

# %% [markdown]
# train 3 class

# %%
Normal151_dir = os.path.join(data_dir,'Normal151')
TB150_dir = os.path.join(data_dir,'TB150')
CA150_dir = os.path.join(data_dir,'CA150')

All_3class_dir = os.path.join(data_dir,'All_3class')

# %% [markdown]
# #### train 3 class
# ข้อมูลใน All_3class_dir รวมภาพทั้ง 3 คลาส รวม 450 ภาพ TB150, Normal151 (เอามาแค่150) และ CA150 (CA คือ lungcancer)

# %%
Normal151_dir = os.path.join(data_dir,'Normal151')
TB150_dir = os.path.join(data_dir,'TB150')
CA150_dir = os.path.join(data_dir,'CA150')

All_3class_dir = os.path.join(data_dir,'All_3class')

# %%
normal = []
for i in range(len(os.listdir(Normal151_dir))):
    img = os.listdir(Normal151_dir)[i]
    normal.append(img)
    
tnormal = pd.DataFrame({'ImageName':[normal][0],
                                       'NameType': "Normal" ,
                                       'NumberType': 0                      })

# %%
tuberculosis = []
for i in range(len(os.listdir(TB150_dir))):
    img = os.listdir(TB150_dir)[i]
    tuberculosis.append(img)

ttuberculosis = pd.DataFrame({'ImageName':[tuberculosis][0],
                                       'NameType': "Tuberculosis" ,
                                       'NumberType': 1                        })

# %%
lungcancer = []
for i in range(len(os.listdir(CA150_dir))):
    img = os.listdir(CA150_dir)[i]
    lungcancer.append(img)

tlungcancer = pd.DataFrame({'ImageName':[lungcancer][0],
                                       'NameType': "Lungcancer" ,
                                       'NumberType': 2                        })

# %%
data_train3 = pd.concat([tnormal[:-1], ttuberculosis, tlungcancer])
data_train3[-3:]
# Out:
#     ImageName    NameType  NumberType
# 147  ca69.jpg  Lungcancer           2
# 148  ca68.jpg  Lungcancer           2
# 149  ca67.jpg  Lungcancer           2

# %% [markdown]
# # K-fold 0-100
# แก้เป็น k-fold หมดแล้ว
# เหลือลองรันว่าจะเจ้งมั้ย
# - 311 layer
# -   filepath มี .h5 ทุกอัน

# %% [markdown]
# ### 8

# %% [markdown]
# #### 8  soft pre bi

# %%
BS = 8
filepath = "Kmodel8_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %%
H_Incep.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
lr = H_Incep.history['lr']

plt.figure(figsize=(20,15))

plt.subplot(2, 2, 1)
plt.plot(lr, label = " Learning rate")

# %% [markdown]
# #### 8 soft pre bi adam

# %%
BS = 8
filepath = "Kmodel8_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:06<00:00, 66.43it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 8 soft pre bi sgd

# %%
BS = 8
filepath = "Kmodel8_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:04<00:00, 90.69it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
# Out:
# Fold #1
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7545 - accuracy: 0.3222
# Epoch 1: val_accuracy improved from -inf to 0.32222, saving model to  Kmodel8_soft_pre_bi_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd1.h5 /assets
# 45/45 [==============================] - 54s 1s/step - loss: 0.7545 - accuracy: 0.3222 - val_loss: 0.8029 - val_accuracy: 0.3222 - lr: 1.0000e-04
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7353 - accuracy: 0.3611
# Epoch 2: val_accuracy improved from 0.32222 to 0.33333, saving model to  Kmodel8_soft_pre_bi_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd1.h5 /assets
# 45/45 [==============================] - 45s 1s/step - loss: 0.7353 - accuracy: 0.3611 - val_loss: 0.7527 - val_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.3806
# Epoch 3: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 252ms/step - loss: 0.7191 - accuracy: 0.3806 - val_loss: 0.7231 - val_accuracy: 0.3111 - lr: 1.0000e-04
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7082 - accuracy: 0.3611
# Epoch 4: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 254ms/step - loss: 0.7082 - accuracy: 0.3611 - val_loss: 0.7038 - val_accuracy: 0.2889 - lr: 1.0000e-04
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.3444
# Epoch 5: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 262ms/step - loss: 0.7014 - accuracy: 0.3444 - val_loss: 0.6910 - val_accuracy: 0.2778 - lr: 1.0000e-04
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.4167
# Epoch 6: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 262ms/step - loss: 0.6893 - accuracy: 0.4167 - val_loss: 0.6816 - val_accuracy: 0.2889 - lr: 1.0000e-04
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.3528
# Epoch 7: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 264ms/step - loss: 0.6869 - accuracy: 0.3528 - val_loss: 0.6738 - val_accuracy: 0.3000 - lr: 1.0000e-04
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6741 - accuracy: 0.3972
# Epoch 8: val_accuracy did not improve from 0.33333
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 45/45 [==============================] - 12s 265ms/step - loss: 0.6741 - accuracy: 0.3972 - val_loss: 0.6677 - val_accuracy: 0.3222 - lr: 1.0000e-04
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6672 - accuracy: 0.4139
# Epoch 9: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 263ms/step - loss: 0.6672 - accuracy: 0.4139 - val_loss: 0.6649 - val_accuracy: 0.3222 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.4500
# Epoch 10: val_accuracy did not improve from 0.33333
# 45/45 [==============================] - 12s 263ms/step - loss: 0.6594 - accuracy: 0.4500 - val_loss: 0.6616 - val_accuracy: 0.3333 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6610 - accuracy: 0.3639
# Epoch 11: val_accuracy improved from 0.33333 to 0.35556, saving model to  Kmodel8_soft_pre_bi_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd1.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6610 - accuracy: 0.3639 - val_loss: 0.6590 - val_accuracy: 0.3556 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6564 - accuracy: 0.4056
# Epoch 12: val_accuracy did not improve from 0.35556
# 45/45 [==============================] - 12s 263ms/step - loss: 0.6564 - accuracy: 0.4056 - val_loss: 0.6564 - val_accuracy: 0.3333 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6544 - accuracy: 0.4083
# Epoch 13: val_accuracy did not improve from 0.35556
# 45/45 [==============================] - 12s 269ms/step - loss: 0.6544 - accuracy: 0.4083 - val_loss: 0.6543 - val_accuracy: 0.3444 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.4583
# Epoch 14: val_accuracy did not improve from 0.35556
# 45/45 [==============================] - 12s 261ms/step - loss: 0.6485 - accuracy: 0.4583 - val_loss: 0.6522 - val_accuracy: 0.3444 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6600 - accuracy: 0.4028
# Epoch 15: val_accuracy did not improve from 0.35556
# 45/45 [==============================] - 12s 266ms/step - loss: 0.6600 - accuracy: 0.4028 - val_loss: 0.6513 - val_accuracy: 0.3444 - lr: 5.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.36      0.14      0.21        28
#       Normal       0.37      0.65      0.47        31
# Tuberculosis       0.28      0.23      0.25        31
#
#     accuracy                           0.34        90
#    macro avg       0.34      0.34      0.31        90
# weighted avg       0.34      0.34      0.31        90
#
# Fold #2
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6500 - accuracy: 0.3889
# Epoch 1: val_accuracy improved from -inf to 0.32222, saving model to  Kmodel8_soft_pre_bi_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6500 - accuracy: 0.3889 - val_loss: 0.6551 - val_accuracy: 0.3222 - lr: 5.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6503 - accuracy: 0.4167
# Epoch 2: val_accuracy improved from 0.32222 to 0.34444, saving model to  Kmodel8_soft_pre_bi_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6503 - accuracy: 0.4167 - val_loss: 0.6532 - val_accuracy: 0.3444 - lr: 5.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6449 - accuracy: 0.4028
# Epoch 3: val_accuracy did not improve from 0.34444
# 45/45 [==============================] - 12s 253ms/step - loss: 0.6449 - accuracy: 0.4028 - val_loss: 0.6511 - val_accuracy: 0.3333 - lr: 5.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.3806
# Epoch 4: val_accuracy did not improve from 0.34444
# 45/45 [==============================] - 11s 251ms/step - loss: 0.6470 - accuracy: 0.3806 - val_loss: 0.6498 - val_accuracy: 0.3333 - lr: 5.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.4083
# Epoch 5: val_accuracy did not improve from 0.34444
# 45/45 [==============================] - 15s 335ms/step - loss: 0.6428 - accuracy: 0.4083 - val_loss: 0.6480 - val_accuracy: 0.3333 - lr: 5.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.4139
# Epoch 6: val_accuracy did not improve from 0.34444
# 45/45 [==============================] - 12s 253ms/step - loss: 0.6440 - accuracy: 0.4139 - val_loss: 0.6473 - val_accuracy: 0.3444 - lr: 5.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.3972
# Epoch 7: val_accuracy improved from 0.34444 to 0.35556, saving model to  Kmodel8_soft_pre_bi_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6425 - accuracy: 0.3972 - val_loss: 0.6450 - val_accuracy: 0.3556 - lr: 5.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.4472
# Epoch 8: val_accuracy improved from 0.35556 to 0.36667, saving model to  Kmodel8_soft_pre_bi_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6377 - accuracy: 0.4472 - val_loss: 0.6429 - val_accuracy: 0.3667 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6274 - accuracy: 0.4917
# Epoch 9: val_accuracy improved from 0.36667 to 0.38889, saving model to  Kmodel8_soft_pre_bi_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd2.h5 /assets
# 45/45 [==============================] - 44s 999ms/step - loss: 0.6274 - accuracy: 0.4917 - val_loss: 0.6416 - val_accuracy: 0.3889 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.4639
# Epoch 10: val_accuracy did not improve from 0.38889
# 45/45 [==============================] - 12s 254ms/step - loss: 0.6314 - accuracy: 0.4639 - val_loss: 0.6408 - val_accuracy: 0.3778 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.4500
# Epoch 11: val_accuracy did not improve from 0.38889
# 45/45 [==============================] - 11s 252ms/step - loss: 0.6307 - accuracy: 0.4500 - val_loss: 0.6393 - val_accuracy: 0.3778 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.4472
# Epoch 12: val_accuracy improved from 0.38889 to 0.40000, saving model to  Kmodel8_soft_pre_bi_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6292 - accuracy: 0.4472 - val_loss: 0.6382 - val_accuracy: 0.4000 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6245 - accuracy: 0.4833
# Epoch 13: val_accuracy did not improve from 0.40000
# 45/45 [==============================] - 12s 254ms/step - loss: 0.6245 - accuracy: 0.4833 - val_loss: 0.6373 - val_accuracy: 0.4000 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6310 - accuracy: 0.4361
# Epoch 14: val_accuracy did not improve from 0.40000
# 45/45 [==============================] - 11s 252ms/step - loss: 0.6310 - accuracy: 0.4361 - val_loss: 0.6357 - val_accuracy: 0.3889 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6232 - accuracy: 0.4694
# Epoch 15: val_accuracy did not improve from 0.40000
# 45/45 [==============================] - 12s 254ms/step - loss: 0.6232 - accuracy: 0.4694 - val_loss: 0.6340 - val_accuracy: 0.4000 - lr: 5.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.58      0.21      0.30        34
#       Normal       0.40      0.52      0.45        27
# Tuberculosis       0.35      0.52      0.42        29
#
#     accuracy                           0.40        90
#    macro avg       0.44      0.41      0.39        90
# weighted avg       0.45      0.40      0.38        90
#
# Fold #3
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6272 - accuracy: 0.4361
# Epoch 1: val_accuracy improved from -inf to 0.44444, saving model to  Kmodel8_soft_pre_bi_sgd3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd3.h5 /assets
# 45/45 [==============================] - 45s 1s/step - loss: 0.6272 - accuracy: 0.4361 - val_loss: 0.6281 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.4333
# Epoch 2: val_accuracy improved from 0.44444 to 0.45556, saving model to  Kmodel8_soft_pre_bi_sgd3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd3.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6265 - accuracy: 0.4333 - val_loss: 0.6274 - val_accuracy: 0.4556 - lr: 5.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.4472
# Epoch 3: val_accuracy did not improve from 0.45556
# 45/45 [==============================] - 12s 255ms/step - loss: 0.6276 - accuracy: 0.4472 - val_loss: 0.6266 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6264 - accuracy: 0.4444
# Epoch 4: val_accuracy did not improve from 0.45556
# 45/45 [==============================] - 12s 254ms/step - loss: 0.6264 - accuracy: 0.4444 - val_loss: 0.6261 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.4833
# Epoch 5: val_accuracy did not improve from 0.45556
# 45/45 [==============================] - 12s 255ms/step - loss: 0.6248 - accuracy: 0.4833 - val_loss: 0.6250 - val_accuracy: 0.4333 - lr: 5.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.4306
# Epoch 6: val_accuracy did not improve from 0.45556
# 45/45 [==============================] - 12s 256ms/step - loss: 0.6258 - accuracy: 0.4306 - val_loss: 0.6241 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.4722
# Epoch 7: val_accuracy did not improve from 0.45556
# 45/45 [==============================] - 12s 261ms/step - loss: 0.6231 - accuracy: 0.4722 - val_loss: 0.6229 - val_accuracy: 0.4556 - lr: 5.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.4361
# Epoch 8: val_accuracy improved from 0.45556 to 0.46667, saving model to  Kmodel8_soft_pre_bi_sgd3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd3.h5 /assets
# 45/45 [==============================] - 47s 1s/step - loss: 0.6262 - accuracy: 0.4361 - val_loss: 0.6220 - val_accuracy: 0.4667 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.4583
# Epoch 9: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 267ms/step - loss: 0.6174 - accuracy: 0.4583 - val_loss: 0.6215 - val_accuracy: 0.4667 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6153 - accuracy: 0.4667
# Epoch 10: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 264ms/step - loss: 0.6153 - accuracy: 0.4667 - val_loss: 0.6208 - val_accuracy: 0.4556 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6154 - accuracy: 0.5056
# Epoch 11: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 263ms/step - loss: 0.6154 - accuracy: 0.5056 - val_loss: 0.6204 - val_accuracy: 0.4556 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.4667
# Epoch 12: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 265ms/step - loss: 0.6182 - accuracy: 0.4667 - val_loss: 0.6195 - val_accuracy: 0.4667 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6173 - accuracy: 0.4694
# Epoch 13: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 260ms/step - loss: 0.6173 - accuracy: 0.4694 - val_loss: 0.6186 - val_accuracy: 0.4667 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6195 - accuracy: 0.4667
# Epoch 14: val_accuracy improved from 0.46667 to 0.47778, saving model to  Kmodel8_soft_pre_bi_sgd3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd3.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6195 - accuracy: 0.4667 - val_loss: 0.6181 - val_accuracy: 0.4778 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6144 - accuracy: 0.4944
# Epoch 15: val_accuracy did not improve from 0.47778
# 45/45 [==============================] - 12s 260ms/step - loss: 0.6144 - accuracy: 0.4944 - val_loss: 0.6173 - val_accuracy: 0.4667 - lr: 5.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.53      0.33      0.41        27
#       Normal       0.50      0.70      0.58        33
# Tuberculosis       0.37      0.33      0.35        30
#
#     accuracy                           0.47        90
#    macro avg       0.47      0.45      0.45        90
# weighted avg       0.47      0.47      0.45        90
#
# Fold #4
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6138 - accuracy: 0.4833
# Epoch 1: val_accuracy improved from -inf to 0.41111, saving model to  Kmodel8_soft_pre_bi_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd4.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6138 - accuracy: 0.4833 - val_loss: 0.6223 - val_accuracy: 0.4111 - lr: 5.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6132 - accuracy: 0.4972
# Epoch 2: val_accuracy improved from 0.41111 to 0.42222, saving model to  Kmodel8_soft_pre_bi_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd4.h5 /assets
# 45/45 [==============================] - 45s 1s/step - loss: 0.6132 - accuracy: 0.4972 - val_loss: 0.6213 - val_accuracy: 0.4222 - lr: 5.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6145 - accuracy: 0.4667
# Epoch 3: val_accuracy did not improve from 0.42222
# 45/45 [==============================] - 12s 261ms/step - loss: 0.6145 - accuracy: 0.4667 - val_loss: 0.6206 - val_accuracy: 0.4000 - lr: 5.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.4889
# Epoch 4: val_accuracy did not improve from 0.42222
# 45/45 [==============================] - 12s 273ms/step - loss: 0.6137 - accuracy: 0.4889 - val_loss: 0.6198 - val_accuracy: 0.4222 - lr: 5.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6119 - accuracy: 0.4944
# Epoch 5: val_accuracy improved from 0.42222 to 0.43333, saving model to  Kmodel8_soft_pre_bi_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd4.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6119 - accuracy: 0.4944 - val_loss: 0.6185 - val_accuracy: 0.4333 - lr: 5.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6064 - accuracy: 0.5278
# Epoch 6: val_accuracy did not improve from 0.43333
# 45/45 [==============================] - 12s 259ms/step - loss: 0.6064 - accuracy: 0.5278 - val_loss: 0.6184 - val_accuracy: 0.4333 - lr: 5.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6113 - accuracy: 0.4889
# Epoch 7: val_accuracy did not improve from 0.43333
# 45/45 [==============================] - 12s 260ms/step - loss: 0.6113 - accuracy: 0.4889 - val_loss: 0.6182 - val_accuracy: 0.4333 - lr: 5.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6165 - accuracy: 0.4639
# Epoch 8: val_accuracy improved from 0.43333 to 0.44444, saving model to  Kmodel8_soft_pre_bi_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd4.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6165 - accuracy: 0.4639 - val_loss: 0.6179 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6114 - accuracy: 0.4556
# Epoch 9: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 259ms/step - loss: 0.6114 - accuracy: 0.4556 - val_loss: 0.6169 - val_accuracy: 0.4333 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.5194
# Epoch 10: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 264ms/step - loss: 0.6048 - accuracy: 0.5194 - val_loss: 0.6160 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.4889
# Epoch 11: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 261ms/step - loss: 0.6082 - accuracy: 0.4889 - val_loss: 0.6155 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6078 - accuracy: 0.4972
# Epoch 12: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 265ms/step - loss: 0.6078 - accuracy: 0.4972 - val_loss: 0.6149 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6009 - accuracy: 0.5556
# Epoch 13: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 265ms/step - loss: 0.6009 - accuracy: 0.5556 - val_loss: 0.6144 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.4972
# Epoch 14: val_accuracy did not improve from 0.44444
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 45/45 [==============================] - 12s 272ms/step - loss: 0.6039 - accuracy: 0.4972 - val_loss: 0.6136 - val_accuracy: 0.4444 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6042 - accuracy: 0.5111
# Epoch 15: val_accuracy improved from 0.44444 to 0.45556, saving model to  Kmodel8_soft_pre_bi_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd4.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.6042 - accuracy: 0.5111 - val_loss: 0.6135 - val_accuracy: 0.4556 - lr: 2.5000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.62      0.27      0.37        30
#       Normal       0.51      0.77      0.62        31
# Tuberculosis       0.30      0.31      0.31        29
#
#     accuracy                           0.46        90
#    macro avg       0.48      0.45      0.43        90
# weighted avg       0.48      0.46      0.43        90
#
# Fold #5
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.5278
# Epoch 1: val_accuracy improved from -inf to 0.43333, saving model to  Kmodel8_soft_pre_bi_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd5.h5 /assets
# 45/45 [==============================] - 45s 1s/step - loss: 0.5976 - accuracy: 0.5278 - val_loss: 0.6160 - val_accuracy: 0.4333 - lr: 2.5000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.4917
# Epoch 2: val_accuracy improved from 0.43333 to 0.44444, saving model to  Kmodel8_soft_pre_bi_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd5.h5 /assets
# 45/45 [==============================] - 45s 1s/step - loss: 0.6031 - accuracy: 0.4917 - val_loss: 0.6152 - val_accuracy: 0.4444 - lr: 2.5000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5973 - accuracy: 0.5278
# Epoch 3: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 265ms/step - loss: 0.5973 - accuracy: 0.5278 - val_loss: 0.6149 - val_accuracy: 0.4222 - lr: 2.5000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5946 - accuracy: 0.5444
# Epoch 4: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 260ms/step - loss: 0.5946 - accuracy: 0.5444 - val_loss: 0.6146 - val_accuracy: 0.4222 - lr: 2.5000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5985 - accuracy: 0.5528
# Epoch 5: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 261ms/step - loss: 0.5985 - accuracy: 0.5528 - val_loss: 0.6148 - val_accuracy: 0.4333 - lr: 2.5000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6015 - accuracy: 0.5306
# Epoch 6: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 257ms/step - loss: 0.6015 - accuracy: 0.5306 - val_loss: 0.6146 - val_accuracy: 0.4333 - lr: 2.5000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.5639
# Epoch 7: val_accuracy improved from 0.44444 to 0.45556, saving model to  Kmodel8_soft_pre_bi_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd5.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.5955 - accuracy: 0.5639 - val_loss: 0.6142 - val_accuracy: 0.4556 - lr: 2.5000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5951 - accuracy: 0.5556
# Epoch 8: val_accuracy did not improve from 0.45556
# 45/45 [==============================] - 12s 265ms/step - loss: 0.5951 - accuracy: 0.5556 - val_loss: 0.6140 - val_accuracy: 0.4333 - lr: 2.5000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5987 - accuracy: 0.5528
# Epoch 9: val_accuracy improved from 0.45556 to 0.46667, saving model to  Kmodel8_soft_pre_bi_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_sgd5.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.5987 - accuracy: 0.5528 - val_loss: 0.6139 - val_accuracy: 0.4667 - lr: 2.5000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6035 - accuracy: 0.4833
# Epoch 10: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 257ms/step - loss: 0.6035 - accuracy: 0.4833 - val_loss: 0.6138 - val_accuracy: 0.4667 - lr: 2.5000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5937 - accuracy: 0.5556
# Epoch 11: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 254ms/step - loss: 0.5937 - accuracy: 0.5556 - val_loss: 0.6130 - val_accuracy: 0.4444 - lr: 2.5000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5931 - accuracy: 0.5750
# Epoch 12: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 262ms/step - loss: 0.5931 - accuracy: 0.5750 - val_loss: 0.6124 - val_accuracy: 0.4333 - lr: 2.5000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5948 - accuracy: 0.5667
# Epoch 13: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 263ms/step - loss: 0.5948 - accuracy: 0.5667 - val_loss: 0.6123 - val_accuracy: 0.4333 - lr: 2.5000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.5278
# Epoch 14: val_accuracy did not improve from 0.46667
# 45/45 [==============================] - 12s 268ms/step - loss: 0.6016 - accuracy: 0.5278 - val_loss: 0.6123 - val_accuracy: 0.4444 - lr: 2.5000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.5472
# Epoch 15: val_accuracy did not improve from 0.46667
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 45/45 [==============================] - 12s 273ms/step - loss: 0.5983 - accuracy: 0.5472 - val_loss: 0.6122 - val_accuracy: 0.4444 - lr: 2.5000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.56      0.29      0.38        31
#       Normal       0.44      0.71      0.55        28
# Tuberculosis       0.38      0.35      0.37        31
#
#     accuracy                           0.44        90
#    macro avg       0.46      0.45      0.43        90
# weighted avg       0.46      0.44      0.43        90
#
#               precision    recall  f1-score   support
#
#   Lungcancer       0.54      0.25      0.34       150
#       Normal       0.44      0.67      0.54       150
# Tuberculosis       0.34      0.35      0.34       150
#
#     accuracy                           0.42       450
#    macro avg       0.44      0.42      0.41       450
# weighted avg       0.44      0.42      0.41       450

# %% [markdown]
# #### 8 soft pre cate

# %%
BS = 8
filepath = "Kmodel8_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:10<00:00, 41.72it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 8 soft pre cate adam

# %%
BS = 8
filepath = "Kmodel8_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:04<00:00, 92.81it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 8 soft pre cate sgd

# %%
BS = 8
filepath = "Kmodel8_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [02:30<00:00,  2.98it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step
# Fold #1
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0936 - accuracy: 0.3611
# Epoch 1: val_accuracy improved from -inf to 0.44444, saving model to  Kmodel8_soft_pre_cate_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd1.h5 /assets
# 45/45 [==============================] - 88s 1s/step - loss: 1.0936 - accuracy: 0.3611 - val_loss: 1.0804 - val_accuracy: 0.4444 - lr: 1.0000e-04
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0769 - accuracy: 0.4250
# Epoch 2: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 263ms/step - loss: 1.0769 - accuracy: 0.4250 - val_loss: 1.1019 - val_accuracy: 0.3667 - lr: 1.0000e-04
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0729 - accuracy: 0.4417
# Epoch 3: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 263ms/step - loss: 1.0729 - accuracy: 0.4417 - val_loss: 1.0999 - val_accuracy: 0.3889 - lr: 1.0000e-04
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0888 - accuracy: 0.3944
# Epoch 4: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 272ms/step - loss: 1.0888 - accuracy: 0.3944 - val_loss: 1.0951 - val_accuracy: 0.3778 - lr: 1.0000e-04
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0593 - accuracy: 0.4333
# Epoch 5: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 11s 252ms/step - loss: 1.0593 - accuracy: 0.4333 - val_loss: 1.0841 - val_accuracy: 0.4222 - lr: 1.0000e-04
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0346 - accuracy: 0.4972
# Epoch 6: val_accuracy did not improve from 0.44444
# 45/45 [==============================] - 12s 254ms/step - loss: 1.0346 - accuracy: 0.4972 - val_loss: 1.0715 - val_accuracy: 0.4444 - lr: 1.0000e-04
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0288 - accuracy: 0.4917
# Epoch 7: val_accuracy did not improve from 0.44444
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 45/45 [==============================] - 12s 264ms/step - loss: 1.0288 - accuracy: 0.4917 - val_loss: 1.0522 - val_accuracy: 0.4444 - lr: 1.0000e-04
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0168 - accuracy: 0.4750
# Epoch 8: val_accuracy improved from 0.44444 to 0.46667, saving model to  Kmodel8_soft_pre_cate_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd1.h5 /assets
# 45/45 [==============================] - 45s 1s/step - loss: 1.0168 - accuracy: 0.4750 - val_loss: 1.0411 - val_accuracy: 0.4667 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0310 - accuracy: 0.4722
# Epoch 9: val_accuracy improved from 0.46667 to 0.50000, saving model to  Kmodel8_soft_pre_cate_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd1.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 1.0310 - accuracy: 0.4722 - val_loss: 1.0345 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0171 - accuracy: 0.5056
# Epoch 10: val_accuracy did not improve from 0.50000
# 45/45 [==============================] - 13s 296ms/step - loss: 1.0171 - accuracy: 0.5056 - val_loss: 1.0270 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0121 - accuracy: 0.5194
# Epoch 11: val_accuracy did not improve from 0.50000
# 45/45 [==============================] - 12s 264ms/step - loss: 1.0121 - accuracy: 0.5194 - val_loss: 1.0205 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0013 - accuracy: 0.5028
# Epoch 12: val_accuracy did not improve from 0.50000
# 45/45 [==============================] - 12s 270ms/step - loss: 1.0013 - accuracy: 0.5028 - val_loss: 1.0156 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0165 - accuracy: 0.4778
# Epoch 13: val_accuracy improved from 0.50000 to 0.52222, saving model to  Kmodel8_soft_pre_cate_sgd1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd1.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 1.0165 - accuracy: 0.4778 - val_loss: 1.0117 - val_accuracy: 0.5222 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9977 - accuracy: 0.5361
# Epoch 14: val_accuracy did not improve from 0.52222
# 45/45 [==============================] - 12s 265ms/step - loss: 0.9977 - accuracy: 0.5361 - val_loss: 1.0086 - val_accuracy: 0.5222 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0039 - accuracy: 0.5083
# Epoch 15: val_accuracy did not improve from 0.52222
# 45/45 [==============================] - 12s 275ms/step - loss: 1.0039 - accuracy: 0.5083 - val_loss: 1.0056 - val_accuracy: 0.5111 - lr: 5.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.50      0.21      0.30        28
#       Normal       0.56      0.74      0.64        31
# Tuberculosis       0.46      0.55      0.50        31
#
#     accuracy                           0.51        90
#    macro avg       0.51      0.50      0.48        90
# weighted avg       0.51      0.51      0.49        90
#
# Fold #2
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9751 - accuracy: 0.5500
# Epoch 1: val_accuracy improved from -inf to 0.53333, saving model to  Kmodel8_soft_pre_cate_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9751 - accuracy: 0.5500 - val_loss: 1.0154 - val_accuracy: 0.5333 - lr: 5.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9876 - accuracy: 0.5500
# Epoch 2: val_accuracy improved from 0.53333 to 0.56667, saving model to  Kmodel8_soft_pre_cate_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9876 - accuracy: 0.5500 - val_loss: 1.0111 - val_accuracy: 0.5667 - lr: 5.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9705 - accuracy: 0.5667
# Epoch 3: val_accuracy improved from 0.56667 to 0.57778, saving model to  Kmodel8_soft_pre_cate_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9705 - accuracy: 0.5667 - val_loss: 1.0098 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9881 - accuracy: 0.5028
# Epoch 4: val_accuracy did not improve from 0.57778
# 45/45 [==============================] - 13s 275ms/step - loss: 0.9881 - accuracy: 0.5028 - val_loss: 1.0055 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9679 - accuracy: 0.5583
# Epoch 5: val_accuracy did not improve from 0.57778
# 45/45 [==============================] - 12s 272ms/step - loss: 0.9679 - accuracy: 0.5583 - val_loss: 1.0026 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9709 - accuracy: 0.5417
# Epoch 6: val_accuracy did not improve from 0.57778
# 45/45 [==============================] - 12s 271ms/step - loss: 0.9709 - accuracy: 0.5417 - val_loss: 1.0003 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9686 - accuracy: 0.5694
# Epoch 7: val_accuracy improved from 0.57778 to 0.58889, saving model to  Kmodel8_soft_pre_cate_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9686 - accuracy: 0.5694 - val_loss: 0.9954 - val_accuracy: 0.5889 - lr: 5.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9457 - accuracy: 0.5889
# Epoch 8: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 264ms/step - loss: 0.9457 - accuracy: 0.5889 - val_loss: 0.9900 - val_accuracy: 0.5889 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9544 - accuracy: 0.5667
# Epoch 9: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 268ms/step - loss: 0.9544 - accuracy: 0.5667 - val_loss: 0.9875 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9500 - accuracy: 0.5722
# Epoch 10: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 269ms/step - loss: 0.9500 - accuracy: 0.5722 - val_loss: 0.9832 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9550 - accuracy: 0.5806
# Epoch 11: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 273ms/step - loss: 0.9550 - accuracy: 0.5806 - val_loss: 0.9796 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9467 - accuracy: 0.5750
# Epoch 12: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 270ms/step - loss: 0.9467 - accuracy: 0.5750 - val_loss: 0.9774 - val_accuracy: 0.5778 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9427 - accuracy: 0.5833
# Epoch 13: val_accuracy improved from 0.58889 to 0.60000, saving model to  Kmodel8_soft_pre_cate_sgd2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd2.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9427 - accuracy: 0.5833 - val_loss: 0.9728 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9459 - accuracy: 0.5722
# Epoch 14: val_accuracy did not improve from 0.60000
# 45/45 [==============================] - 12s 266ms/step - loss: 0.9459 - accuracy: 0.5722 - val_loss: 0.9692 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9259 - accuracy: 0.6000
# Epoch 15: val_accuracy did not improve from 0.60000
# 45/45 [==============================] - 12s 269ms/step - loss: 0.9259 - accuracy: 0.6000 - val_loss: 0.9669 - val_accuracy: 0.6000 - lr: 5.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.71      0.35      0.47        34
#       Normal       0.67      0.96      0.79        27
# Tuberculosis       0.47      0.55      0.51        29
#
#     accuracy                           0.60        90
#    macro avg       0.61      0.62      0.59        90
# weighted avg       0.62      0.60      0.58        90
#
# Fold #3
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9361 - accuracy: 0.5806
# Epoch 1: val_accuracy improved from -inf to 0.66667, saving model to  Kmodel8_soft_pre_cate_sgd3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd3.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9361 - accuracy: 0.5806 - val_loss: 0.9065 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.6056
# Epoch 2: val_accuracy did not improve from 0.66667
# 45/45 [==============================] - 12s 263ms/step - loss: 0.9217 - accuracy: 0.6056 - val_loss: 0.9034 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9256 - accuracy: 0.6000
# Epoch 3: val_accuracy did not improve from 0.66667
# 45/45 [==============================] - 12s 258ms/step - loss: 0.9256 - accuracy: 0.6000 - val_loss: 0.9004 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9160 - accuracy: 0.6333
# Epoch 4: val_accuracy did not improve from 0.66667
# 45/45 [==============================] - 12s 265ms/step - loss: 0.9160 - accuracy: 0.6333 - val_loss: 0.8989 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.5944
# Epoch 5: val_accuracy improved from 0.66667 to 0.68889, saving model to  Kmodel8_soft_pre_cate_sgd3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd3.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9244 - accuracy: 0.5944 - val_loss: 0.8941 - val_accuracy: 0.6889 - lr: 5.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9156 - accuracy: 0.6139
# Epoch 6: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 267ms/step - loss: 0.9156 - accuracy: 0.6139 - val_loss: 0.8911 - val_accuracy: 0.6778 - lr: 5.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9292 - accuracy: 0.5722
# Epoch 7: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 264ms/step - loss: 0.9292 - accuracy: 0.5722 - val_loss: 0.8872 - val_accuracy: 0.6778 - lr: 5.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9123 - accuracy: 0.6000
# Epoch 8: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 264ms/step - loss: 0.9123 - accuracy: 0.6000 - val_loss: 0.8835 - val_accuracy: 0.6778 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9163 - accuracy: 0.5861
# Epoch 9: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 266ms/step - loss: 0.9163 - accuracy: 0.5861 - val_loss: 0.8813 - val_accuracy: 0.6889 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8934 - accuracy: 0.6278
# Epoch 10: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 268ms/step - loss: 0.8934 - accuracy: 0.6278 - val_loss: 0.8777 - val_accuracy: 0.6889 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8884 - accuracy: 0.6222
# Epoch 11: val_accuracy did not improve from 0.68889
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 45/45 [==============================] - 12s 265ms/step - loss: 0.8884 - accuracy: 0.6222 - val_loss: 0.8736 - val_accuracy: 0.6889 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8958 - accuracy: 0.6611
# Epoch 12: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 265ms/step - loss: 0.8958 - accuracy: 0.6611 - val_loss: 0.8721 - val_accuracy: 0.6889 - lr: 2.5000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8945 - accuracy: 0.6111
# Epoch 13: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 268ms/step - loss: 0.8945 - accuracy: 0.6111 - val_loss: 0.8718 - val_accuracy: 0.6889 - lr: 2.5000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9040 - accuracy: 0.6056
# Epoch 14: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 258ms/step - loss: 0.9040 - accuracy: 0.6056 - val_loss: 0.8703 - val_accuracy: 0.6889 - lr: 2.5000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8875 - accuracy: 0.6333
# Epoch 15: val_accuracy did not improve from 0.68889
# 45/45 [==============================] - 12s 262ms/step - loss: 0.8875 - accuracy: 0.6333 - val_loss: 0.8683 - val_accuracy: 0.6889 - lr: 2.5000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.87      0.48      0.62        27
#       Normal       0.72      0.85      0.78        33
# Tuberculosis       0.58      0.70      0.64        30
#
#     accuracy                           0.69        90
#    macro avg       0.72      0.68      0.68        90
# weighted avg       0.72      0.69      0.68        90
#
# Fold #4
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8983 - accuracy: 0.6083
# Epoch 1: val_accuracy improved from -inf to 0.62222, saving model to  Kmodel8_soft_pre_cate_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd4.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.8983 - accuracy: 0.6083 - val_loss: 0.8721 - val_accuracy: 0.6222 - lr: 2.5000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9089 - accuracy: 0.6000
# Epoch 2: val_accuracy improved from 0.62222 to 0.63333, saving model to  Kmodel8_soft_pre_cate_sgd4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd4.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.9089 - accuracy: 0.6000 - val_loss: 0.8680 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9005 - accuracy: 0.6222
# Epoch 3: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 256ms/step - loss: 0.9005 - accuracy: 0.6222 - val_loss: 0.8664 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8962 - accuracy: 0.6056
# Epoch 4: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 264ms/step - loss: 0.8962 - accuracy: 0.6056 - val_loss: 0.8656 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9091 - accuracy: 0.5861
# Epoch 5: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 271ms/step - loss: 0.9091 - accuracy: 0.5861 - val_loss: 0.8641 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9112 - accuracy: 0.6028
# Epoch 6: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 266ms/step - loss: 0.9112 - accuracy: 0.6028 - val_loss: 0.8645 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8773 - accuracy: 0.6306
# Epoch 7: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 269ms/step - loss: 0.8773 - accuracy: 0.6306 - val_loss: 0.8629 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8802 - accuracy: 0.6417
# Epoch 8: val_accuracy did not improve from 0.63333
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 45/45 [==============================] - 12s 270ms/step - loss: 0.8802 - accuracy: 0.6417 - val_loss: 0.8631 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8803 - accuracy: 0.6111
# Epoch 9: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 13s 279ms/step - loss: 0.8803 - accuracy: 0.6111 - val_loss: 0.8609 - val_accuracy: 0.6333 - lr: 1.2500e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8835 - accuracy: 0.6083
# Epoch 10: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 271ms/step - loss: 0.8835 - accuracy: 0.6083 - val_loss: 0.8613 - val_accuracy: 0.6333 - lr: 1.2500e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8759 - accuracy: 0.5861
# Epoch 11: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 273ms/step - loss: 0.8759 - accuracy: 0.5861 - val_loss: 0.8584 - val_accuracy: 0.6333 - lr: 1.2500e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9075 - accuracy: 0.5667
# Epoch 12: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 13s 275ms/step - loss: 0.9075 - accuracy: 0.5667 - val_loss: 0.8570 - val_accuracy: 0.6333 - lr: 1.2500e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8996 - accuracy: 0.5833
# Epoch 13: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 269ms/step - loss: 0.8996 - accuracy: 0.5833 - val_loss: 0.8556 - val_accuracy: 0.6333 - lr: 1.2500e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8999 - accuracy: 0.6083
# Epoch 14: val_accuracy did not improve from 0.63333
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-05.
# 45/45 [==============================] - 12s 268ms/step - loss: 0.8999 - accuracy: 0.6083 - val_loss: 0.8553 - val_accuracy: 0.6333 - lr: 1.2500e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8995 - accuracy: 0.5889
# Epoch 15: val_accuracy did not improve from 0.63333
# 45/45 [==============================] - 12s 271ms/step - loss: 0.8995 - accuracy: 0.5889 - val_loss: 0.8558 - val_accuracy: 0.6333 - lr: 1.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.71      0.50      0.59        30
#       Normal       0.69      0.81      0.75        31
# Tuberculosis       0.52      0.59      0.55        29
#
#     accuracy                           0.63        90
#    macro avg       0.64      0.63      0.63        90
# weighted avg       0.64      0.63      0.63        90
#
# Fold #5
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8552 - accuracy: 0.6528
# Epoch 1: val_accuracy improved from -inf to 0.57778, saving model to  Kmodel8_soft_pre_cate_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd5.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.8552 - accuracy: 0.6528 - val_loss: 0.9041 - val_accuracy: 0.5778 - lr: 1.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8769 - accuracy: 0.6111
# Epoch 2: val_accuracy improved from 0.57778 to 0.58889, saving model to  Kmodel8_soft_pre_cate_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd5.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.8769 - accuracy: 0.6111 - val_loss: 0.9040 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8803 - accuracy: 0.6250
# Epoch 3: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 264ms/step - loss: 0.8803 - accuracy: 0.6250 - val_loss: 0.9032 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8430 - accuracy: 0.6750
# Epoch 4: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 270ms/step - loss: 0.8430 - accuracy: 0.6750 - val_loss: 0.9051 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8774 - accuracy: 0.6250
# Epoch 5: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 268ms/step - loss: 0.8774 - accuracy: 0.6250 - val_loss: 0.9048 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8788 - accuracy: 0.6417
# Epoch 6: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 274ms/step - loss: 0.8788 - accuracy: 0.6417 - val_loss: 0.9047 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8780 - accuracy: 0.6361
# Epoch 7: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 13s 282ms/step - loss: 0.8780 - accuracy: 0.6361 - val_loss: 0.9046 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8709 - accuracy: 0.6444
# Epoch 8: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 272ms/step - loss: 0.8709 - accuracy: 0.6444 - val_loss: 0.9038 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8701 - accuracy: 0.6389
# Epoch 9: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 263ms/step - loss: 0.8701 - accuracy: 0.6389 - val_loss: 0.9009 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8539 - accuracy: 0.6389
# Epoch 10: val_accuracy did not improve from 0.58889
# 45/45 [==============================] - 12s 261ms/step - loss: 0.8539 - accuracy: 0.6389 - val_loss: 0.9017 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8742 - accuracy: 0.6583
# Epoch 11: val_accuracy improved from 0.58889 to 0.60000, saving model to  Kmodel8_soft_pre_cate_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd5.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.8742 - accuracy: 0.6583 - val_loss: 0.9004 - val_accuracy: 0.6000 - lr: 1.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8722 - accuracy: 0.6194
# Epoch 12: val_accuracy did not improve from 0.60000
# 45/45 [==============================] - 12s 268ms/step - loss: 0.8722 - accuracy: 0.6194 - val_loss: 0.8993 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8541 - accuracy: 0.6528
# Epoch 13: val_accuracy improved from 0.60000 to 0.61111, saving model to  Kmodel8_soft_pre_cate_sgd5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_cate_sgd5.h5 /assets
# 45/45 [==============================] - 46s 1s/step - loss: 0.8541 - accuracy: 0.6528 - val_loss: 0.8974 - val_accuracy: 0.6111 - lr: 1.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8667 - accuracy: 0.6333
# Epoch 14: val_accuracy did not improve from 0.61111
# 45/45 [==============================] - 12s 265ms/step - loss: 0.8667 - accuracy: 0.6333 - val_loss: 0.8999 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8654 - accuracy: 0.6417
# Epoch 15: val_accuracy did not improve from 0.61111
# 45/45 [==============================] - 12s 267ms/step - loss: 0.8654 - accuracy: 0.6417 - val_loss: 0.8984 - val_accuracy: 0.5889 - lr: 1.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       0.73      0.35      0.48        31
#       Normal       0.59      0.79      0.68        28
# Tuberculosis       0.53      0.65      0.58        31
#
#     accuracy                           0.59        90
#    macro avg       0.62      0.60      0.58        90
# weighted avg       0.62      0.59      0.58        90
#
#               precision    recall  f1-score   support
#
#   Lungcancer       0.71      0.38      0.50       150
#       Normal       0.65      0.83      0.73       150
# Tuberculosis       0.51      0.61      0.55       150
#
#     accuracy                           0.60       450
#    macro avg       0.62      0.60      0.59       450
# weighted avg       0.62      0.60      0.59       450

# %% [markdown]
# ### 16

# %% [markdown]
# #### 16  soft pre bi

# %%
BS = 16
filepath = "Kmodel16_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:04<00:00, 90.16it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
# Out:
# Fold #1
# Epoch 1/100
# 22/22 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.6715
# Epoch 1: val_accuracy improved from -inf to 0.34444, saving model to  Kmodel16_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel16_soft_pre_bi1.h5 /assets
# 22/22 [==============================] - 61s 2s/step - loss: 0.4544 - accuracy: 0.6715 - val_loss: 0.9211 - val_accuracy: 0.3444 - lr: 1.0000e-04
# Epoch 2/100
# 22/22 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8227
# Epoch 2: val_accuracy did not improve from 0.34444
# 22/22 [==============================] - 11s 481ms/step - loss: 0.2878 - accuracy: 0.8227 - val_loss: 1.0831 - val_accuracy: 0.3444 - lr: 1.0000e-04
# Epoch 3/100
# 21/22 [===========================>..] - ETA: 0s - loss: 0.2226 - accuracy: 0.8354
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-45a07b344954> in <module>()
#      37                                                     validation_data=(x_test_Incep, y_test_Incep),
#      38                                                     steps_per_epoch=len(x_train_Incep) // BS,
# ---> 39 	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])
#      40
#      41     pred_Incep = model_Incep.predict(x_test_Incep)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# #### 16 soft pre bi adam

# %%
BS = 16
filepath = "Kmodel16_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre bi sgd

# %%
BS = 16
filepath = "Kmodel16_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre cate

# %%
BS = 16
filepath = "Kmodel16_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ####16 soft pre cate adam

# %%
BS = 16                                                       ##
filepath = "Kmodel16_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre cate sgd

# %%
BS = 16                                                       ##
filepath = "Kmodel16_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ### 32

# %% [markdown]
# #### 32  soft pre bi

# %%
BS = 32
filepath = "Kmodel32_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre bi adam

# %%
BS = 32
filepath = "Kmodel32_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre bi sgd

# %%
BS = 32
filepath = "Kmodel32_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre cate

# %%
BS = 32
filepath = "Kmodel32_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre cate adam

# %%
BS = 32
filepath = "Kmodel32_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre cate sgd

# %%
BS = 32
filepath = "Kmodel32_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ### 1

# %% [markdown]
# #### 1  soft pre bi

# %%
BS = 1
filepath = "Kmodel1_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre bi adam

# %%
BS = 1
filepath = "Kmodel1_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre bi sgd

# %%
BS = 1
filepath = "Kmodel1_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre cate

# %%
BS = 1
filepath = "Kmodel1_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre cate adam

# %%
BS = 1
filepath = "Kmodel1_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre cate sgd

# %%
BS = 1
filepath = "Kmodel1_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
