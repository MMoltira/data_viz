# %% [markdown]
# <a href="https://colab.research.google.com/github/MMoltira/data_viz/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import แพคเกจ pandas เปลี่ยนชื่อเป็น pd

# %%
from google.colab import drive #เชื่อม Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
day1 = pd.read_excel('/content/drive/My Drive/DWDM_material/-.57-.58-1.xls',sheet_name=0,skiprows=1)
day1 #head คือดูแค่หัวตาราง
# Out:
#     สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557  ...                Unnamed: 8
# 0        สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 1                                               NaN  ...                       NaN
# 2                                             ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 3                                               ที่  ...                       NaN
# 4                                                 1  ...   เป็นผู้ให้บริการจำหน่าย
# 5                                                 2  ...   เป็นผู้ให้บริการจำหน่าย
# 6                                                 3  ...   เป็นผู้ให้บริการจำหน่าย
# 7                                                 4  ...   เป็นผู้ให้บริการจำหน่าย
# 8                                                 5  ...   เป็นผู้ให้บริการจำหน่าย
# 9                                                 6  ...   เป็นผู้ให้บริการจำหน่าย
# ...
