# %% [markdown]
# <a href="https://colab.research.google.com/github/MMoltira/data_viz/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import แพคเกจ pandas เปลี่ยนชื่อเป็น pd

# %%
from google.colab import drive #เชื่อม Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
day1 = pd.read_excel('/content/drive/My Drive/DWDM_material/-.57-.58-1.xls',sheet_name=0,skiprows=1)
day1 #head คือดูแค่หัวตาราง
# Out:
#     สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557  ...                Unnamed: 8
# 0        สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 1                                               NaN  ...                       NaN
# 2                                             ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 3                                               ที่  ...                       NaN
# 4                                                 1  ...   เป็นผู้ให้บริการจำหน่าย
# 5                                                 2  ...   เป็นผู้ให้บริการจำหน่าย
# 6                                                 3  ...   เป็นผู้ให้บริการจำหน่าย
# 7                                                 4  ...   เป็นผู้ให้บริการจำหน่าย
# 8                                                 5  ...   เป็นผู้ให้บริการจำหน่าย
# 9                                                 6  ...   เป็นผู้ให้บริการจำหน่าย
# ...

# %% [markdown]
# ## HW 8
# แก้ให้เสร็จ ส่งเป็น HW

# %%
oct2557 = day1
oct2557 = oct2557.dropna()
oct2557
# Out:
#    สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557  ...               Unnamed: 8
# 4                                                1  ...  เป็นผู้ให้บริการจำหน่าย
# 5                                                2  ...  เป็นผู้ให้บริการจำหน่าย
# 6                                                3  ...  เป็นผู้ให้บริการจำหน่าย
# 7                                                4  ...  เป็นผู้ให้บริการจำหน่าย
# 8                                                5  ...  เป็นผู้ให้บริการจำหน่าย
# 9                                                6  ...  เป็นผู้ให้บริการจำหน่าย
# 10                                               7  ...  เป็นผู้ให้บริการจำหน่าย
# 11                                               8  ...  เป็นผู้ให้บริการจำหน่าย
# 12                                               9  ...  เป็นผู้ให้บริการจำหน่าย
# 13                                              10  ...  เป็นผู้ให้บริการจำหน่าย
# 14                                              11  ...  เป็นผู้ให้บริการจำหน่าย
# ...

# %%
oct2557 = oct2557.rename(columns={'Unnamed: 5' : 'ราคาเสนอ', 'Unnamed: 7': 'ราคาซื้อ','Unnamed: 1' : 'งานจัดซื้อ', 'Unnamed: 2': 'วงเงินงบประมาณ','Unnamed: 3' : 'วิธีซื้อ', 'Unnamed: 4': 'ผู้เสนอราคาและราคาที่เสนอ','Unnamed: 6' : 'ผู้ได้รับการคัดเลือกและราคา', 'Unnamed: 8': 'เหตุผลที่คัดเลือกโดยสรุป', 'สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557': 'ลำดับ'})
oct2557
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 4      1  ...  เป็นผู้ให้บริการจำหน่าย
# 5      2  ...  เป็นผู้ให้บริการจำหน่าย
# 6      3  ...  เป็นผู้ให้บริการจำหน่าย
# 7      4  ...  เป็นผู้ให้บริการจำหน่าย
# 8      5  ...  เป็นผู้ให้บริการจำหน่าย
# 9      6  ...  เป็นผู้ให้บริการจำหน่าย
# 10     7  ...  เป็นผู้ให้บริการจำหน่าย
# 11     8  ...  เป็นผู้ให้บริการจำหน่าย
# 12     9  ...  เป็นผู้ให้บริการจำหน่าย
# 13    10  ...  เป็นผู้ให้บริการจำหน่าย
# 14    11  ...  เป็นผู้ให้บริการจำหน่าย
# 15    12  ...  เป็นผู้ให้บริการจำหน่าย
# 16    13  ...  เป็นผู้ให้บริการจำหน่าย
# 17    14  ...  เป็นผู้ให้บริการจำหน่าย
# 18    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %%
day2 = pd.read_excel('/content/drive/My Drive/DWDM_material/-.57-.58-1.xls',sheet_name='พย.57',header=4, skipfooter=30)
day2 #head คือดูแค่หัวตาราง
# Out:
#                                                 ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 0                                                 ที่  ...                       NaN
# 1                                                   1  ...   เป็นผู้ให้บริการจำหน่าย
# 2                                                   2  ...            เป็นผู้จำหน่าย
# 3                                                   3  ...            เป็นผู้จำหน่าย
# 4                                                   4  ...            เป็นผู้จำหน่าย
# 5                                                   5  ...            เป็นผู้จำหน่าย
# 6                                                   6  ...            เป็นผู้จำหน่าย
# 7                                                   7  ...            เป็นผู้จำหน่าย
# 8                                                   8  ...            เป็นผู้จำหน่าย
# 9                                                   9  ...            เป็นผู้จำหน่าย
# ...

# %%
nov2557 = day2
nov2557 = nov2557.dropna()
nov2557
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...

# %%
nov2557 = nov2557.rename(columns={'Unnamed: 5' : 'ราคาเสนอ', 'Unnamed: 7': 'ราคาซื้อ'})
nov2557
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...

# %%
Oct_Nov2557 = pd.concat([oct2557,nov2557]) 
Oct_Nov2557
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 4      1  ...  เป็นผู้ให้บริการจำหน่าย
# 5      2  ...  เป็นผู้ให้บริการจำหน่าย
# 6      3  ...  เป็นผู้ให้บริการจำหน่าย
# 7      4  ...  เป็นผู้ให้บริการจำหน่าย
# 8      5  ...  เป็นผู้ให้บริการจำหน่าย
# 9      6  ...  เป็นผู้ให้บริการจำหน่าย
# 10     7  ...  เป็นผู้ให้บริการจำหน่าย
# 11     8  ...  เป็นผู้ให้บริการจำหน่าย
# 12     9  ...  เป็นผู้ให้บริการจำหน่าย
# 13    10  ...  เป็นผู้ให้บริการจำหน่าย
# 14    11  ...  เป็นผู้ให้บริการจำหน่าย
# 15    12  ...  เป็นผู้ให้บริการจำหน่าย
# 16    13  ...  เป็นผู้ให้บริการจำหน่าย
# 17    14  ...  เป็นผู้ให้บริการจำหน่าย
# 18    15  ...  เป็นผู้ให้บริการจำหน่าย
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# ...
